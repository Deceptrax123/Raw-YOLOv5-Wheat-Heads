# %%
#notebook of all code experiments
import pandas as pd 
import numpy as np

# %%
dataset=pd.read_csv("./train/train.csv")
dataset
# Out:
#                                              image_name  \
# 0     7b73239dfd89b06c03e1be81cc5074ec47ae048305ec63...
# 1     0e37ccf64ccbd456f07dcfe110133018f324e5bdf63b08...
# 2     89e0aa4148f0a9ff01e9e55c5a2bcbe294150444dbe43c...
# 3     fed8dde94c7a51de782b71f45c9115cdf7208cf7f33eee...
# 4     8a593fc7894c37145d302bce36822bf21725088cf17b23...
# ...                                                 ...
# 3652  a7a7fc8914a720073e2bad3f2981a869ea54a0eba3adde...
# 3653  303cfef6aa1483f7377292eac942b2c80ef17d8ab347ed...
# 3654  99ecf64fab884c431969a12eb28ad29041aa190498d3ae...
# 3655  a543d8ab29e27fbd7fd96fa5f48ed2e84592c1372583bc...
# 3656  618d3e5f3a932a9b6c877976ce9e512a6229b63b38bab8...
#
#                                             BoxesString  domain
# 0     949 967 999 994;368 649 443 685;118 280 185 33...       0
# 1     691 60 730 119;838 901 897 969;477 444 526 489...       0
# 2     953 178 1023 244;265 164 326 228;657 790 689 8...       0
# ...

# %%
import torch 

model=torch.hub.load("ultralytics/yolov5",'yolov5s',autoshape=False,pretrained=False).to(device=torch.device('mps'))
# Out:
# /Users/smudge/Desktop/Code/research/Wheat-Head-Detection/.venv/lib/python3.11/site-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /Users/smudge/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-9-28 Python-3.11.4 torch-2.0.1 CPU
#
#
#                  from  n    params  module                                  arguments
# ...

# %%
model
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): C3(
#       (cv1): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Conv(
#         (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
# ...

# %%
images=list(dataset['image_name'])
boxes=list(dataset['BoxesString'])

data_dict=dict(zip(images,boxes))

# %%
data_dict
# Out:
# {'7b73239dfd89b06c03e1be81cc5074ec47ae048305ec6377b692a7df579723d1': '949 967 999 994;368 649 443 685;118 280 185 333;899 564 947 609;604 243 682 297;178 613 220 647;18 598 71 655;96 929 119 957;503 588 558 710;800 221 853 280;344 792 398 844;8 457 86 566;856 508 908 555;275 961 341 1022;707 874 757 940;495 401 554 460;947 85 1023 131;328 196 403 257;811 63 876 134;999 228 1022 317;400 975 478 1022;731 838 779 880;68 557 130 648;252 52 301 113;913 517 947 545;92 757 142 863;133 809 177 892;962 929 1003 1002;451 0 507 60;660 558 698 594;818 696 877 740;740 631 797 697;173 90 212 133;915 414 998 484;493 226 533 269;603 361 629 398;676 94 735 131;200 761 244 817;272 683 356 767;323 115 355 157;161 924 278 1018;587 303 645 358;48 970 120 1022;657 696 723 742',
# ...

# %%
from generate_annotations import create_dict,prepare_for_yolov5

dataset=create_dict()

for i in dataset:
    prepare_for_yolov5(i)

# %%
import os
images=[os.path.join('./train/train/',x) for x in os.listdir('./train/train/')]
annotations=[os.path.join('./annotations/',x) for x in os.listdir('./annotations/')]

# %%
images.sort()
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
annotations.sort()

# %%
annotations
# Out:
# ['./annotations/000be778dbb878bf22db3a3525d9722d7f2a49a3a1fb49321c1a43beabd88c06.txt',
#  './annotations/001be48ccfab560e650dc0a4cceeb1636844520c88267e215ec9987688566931.txt',
#  './annotations/003c89679439f746a046c4a89aad17ff32d4e0fe0be96c17518a8f972f31b30d.txt',
#  './annotations/007b9fa7360dd0e511b7663287b3237299123b03380da0ee90de998b7d5c573f.txt',
#  './annotations/00838a686139533d9d3bc6d67768bf8ef9829d25cb879c3cd90969deb51c0c62.txt',
#  './annotations/008b7655928e8d4ced39bb44dca79b4a79fd593c38e0444ff77c2cf64314b1e7.txt',
#  './annotations/008c61e7d4e715750e9f9ffff6ca4613561d629c0657afcc85a1faf7dcf8c4e6.txt',
#  './annotations/008e4196f47d50b0385d14a9955a7e2598457a22ccd4a5b1c8d31df16dd1c3ba.txt',
#  './annotations/008f08a117500732b6fd986fe37a2d79fc87446cb350cf811dcf856a2831bf97.txt',
#  './annotations/00982ddd10513ed92354260324b9c5f74b8dfff26df2b4b75833a4e041eacc5f.txt',
#  './annotations/00ab9e75ba68b9c4d37edd769c98fe728c61b5349915d30eb8f20298a40f5949.txt',
# ...

# %%
images
# Out:
# ['./train/train/000be778dbb878bf22db3a3525d9722d7f2a49a3a1fb49321c1a43beabd88c06.png',
#  './train/train/001be48ccfab560e650dc0a4cceeb1636844520c88267e215ec9987688566931.png',
#  './train/train/003c89679439f746a046c4a89aad17ff32d4e0fe0be96c17518a8f972f31b30d.png',
#  './train/train/007b9fa7360dd0e511b7663287b3237299123b03380da0ee90de998b7d5c573f.png',
#  './train/train/00838a686139533d9d3bc6d67768bf8ef9829d25cb879c3cd90969deb51c0c62.png',
#  './train/train/008b7655928e8d4ced39bb44dca79b4a79fd593c38e0444ff77c2cf64314b1e7.png',
#  './train/train/008c61e7d4e715750e9f9ffff6ca4613561d629c0657afcc85a1faf7dcf8c4e6.png',
#  './train/train/008e4196f47d50b0385d14a9955a7e2598457a22ccd4a5b1c8d31df16dd1c3ba.png',
#  './train/train/008f08a117500732b6fd986fe37a2d79fc87446cb350cf811dcf856a2831bf97.png',
#  './train/train/00982ddd10513ed92354260324b9c5f74b8dfff26df2b4b75833a4e041eacc5f.png',
#  './train/train/00ab9e75ba68b9c4d37edd769c98fe728c61b5349915d30eb8f20298a40f5949.png',
# ...
